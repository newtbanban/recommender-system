# %% [markdown]
# <i>Copyright (c) Recommenders contributors.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # SAR Single Node on MovieLens (Python, CPU)
#
# Simple Algorithm for Recommendation (SAR) is a fast and scalable algorithm for personalized recommendations based on user transaction history. It produces easily explainable and interpretable recommendations and handles "cold item" and "semi-cold user" scenarios. SAR is a kind of neighborhood based algorithm (as discussed in [Recommender Systems by Aggarwal](https://dl.acm.org/citation.cfm?id=2931100)) which is intended for ranking top items for each user. More details about SAR can be found in the [deep dive notebook](../02_model_collaborative_filtering/sar_deep_dive.ipynb).
#
# SAR recommends items that are most ***similar*** to the ones that the user already has an existing ***affinity*** for. Two items are ***similar*** if the users that interacted with one item are also likely to have interacted with the other. A user has an ***affinity*** to an item if they have interacted with it in the past.
#
# ### Advantages of SAR:
# - High accuracy for an easy to train and deploy algorithm
# - Fast training, only requiring simple counting to construct matrices used at prediction time.
# - Fast scoring, only involving multiplication of the similarity matrix with an affinity vector
#
# ### Notes to use SAR properly:
# - Since it does not use item or user features, it can be at a disadvantage against algorithms that do.
# - It's memory-hungry, requiring the creation of an $mxm$ sparse square matrix (where $m$ is the number of items). This can also be a problem for many matrix factorization algorithms.
# - SAR favors an implicit rating scenario and it does not predict ratings.
#
# This notebook provides an example of how to utilize and evaluate SAR in Python on a CPU.

# %% [markdown]
# # 0 Global Settings and Imports

# %%
# !pip3 install recommenders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: recommenders in /Users/newt/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: category-encoders<3,>=2.6.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (2.6.4)
# Requirement already satisfied: cornac<3,>=1.15.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (2.3.5)
# Requirement already satisfied: hyperopt<1,>=0.2.7 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (0.2.7)
# Requirement already satisfied: lightgbm<5,>=4.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (4.6.0)
# Requirement already satisfied: locust<3,>=2.12.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (2.34.0)
# Requirement already satisfied: memory-profiler<1,>=0.61.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (0.61.0)
# Requirement already satisfied: nltk<4,>=3.8.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (3.9.2)
# Requirement already satisfied: notebook<8,>=6.5.5 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (7.5.1)
# Requirement already satisfied: numba<1,>=0.57.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (0.60.0)
# Requirement already satisfied: pandas<3.0.0,>2.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (2.3.3)
# Requirement already satisfied: retrying<2,>=1.3.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (1.4.2)
# Requirement already satisfied: scikit-learn<2,>=1.2.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (1.6.1)
# Requirement already satisfied: scikit-surprise>=1.1.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (1.1.4)
# Requirement already satisfied: seaborn<1,>=0.13.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (0.13.2)
# Requirement already satisfied: transformers<5,>=4.27.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (4.57.3)
# Requirement already satisfied: pandera>=0.15.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.26.1)
# Requirement already satisfied: statsmodels>=0.14.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from recommenders) (0.14.6)
# Requirement already satisfied: numpy>=1.14.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from category-encoders<3,>=2.6.0->recommenders) (2.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from category-encoders<3,>=2.6.0->recommenders) (1.13.1)
# Requirement already satisfied: patsy>=0.5.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from category-encoders<3,>=2.6.0->recommenders) (1.0.2)
# Requirement already satisfied: tqdm in /Users/newt/Library/Python/3.9/lib/python/site-packages (from cornac<3,>=1.15.2->recommenders) (4.67.1)
# Requirement already satisfied: powerlaw in /Users/newt/Library/Python/3.9/lib/python/site-packages (from cornac<3,>=1.15.2->recommenders) (1.5)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from hyperopt<1,>=0.2.7->recommenders) (1.15.0)
# Requirement already satisfied: networkx>=2.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from hyperopt<1,>=0.2.7->recommenders) (3.2.1)
# Requirement already satisfied: future in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from hyperopt<1,>=0.2.7->recommenders) (0.18.2)
# Requirement already satisfied: cloudpickle in /Users/newt/Library/Python/3.9/lib/python/site-packages (from hyperopt<1,>=0.2.7->recommenders) (3.1.2)
# Requirement already satisfied: py4j in /Users/newt/Library/Python/3.9/lib/python/site-packages (from hyperopt<1,>=0.2.7->recommenders) (0.10.9.9)
# Requirement already satisfied: configargparse>=1.5.5 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (1.7.1)
# Requirement already satisfied: flask-cors>=3.0.10 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (6.0.2)
# Requirement already satisfied: flask-login>=0.6.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (0.6.3)
# Requirement already satisfied: flask>=2.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (3.1.2)
# Requirement already satisfied: gevent>=22.10.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (25.9.1)
# Requirement already satisfied: geventhttpclient>=2.3.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (2.3.7)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (1.1.2)
# Requirement already satisfied: psutil>=5.9.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (7.1.3)
# Requirement already satisfied: pyzmq>=25.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (27.1.0)
# Requirement already satisfied: requests>=2.26.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (2.32.5)
# Requirement already satisfied: setuptools>=70.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (80.9.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (2.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (4.15.0)
# Requirement already satisfied: werkzeug>=2.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from locust<3,>=2.12.2->recommenders) (3.1.4)
# Requirement already satisfied: click in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nltk<4,>=3.8.1->recommenders) (8.1.8)
# Requirement already satisfied: joblib in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nltk<4,>=3.8.1->recommenders) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nltk<4,>=3.8.1->recommenders) (2025.11.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from notebook<8,>=6.5.5->recommenders) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from notebook<8,>=6.5.5->recommenders) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from notebook<8,>=6.5.5->recommenders) (4.5.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from notebook<8,>=6.5.5->recommenders) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from notebook<8,>=6.5.5->recommenders) (6.5.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.12.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (8.7.0)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (6.31.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (2.3.0)
# Requirement already satisfied: certifi in /Users/newt/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/newt/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (1.0.9)
# Requirement already satisfied: idna in /Users/newt/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (4.25.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from numba<1,>=0.57.0->recommenders) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2,>=1.2.0->recommenders) (3.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from seaborn<1,>=0.13.0->recommenders) (3.9.4)
# Requirement already satisfied: filelock in /Users/newt/Library/Python/3.9/lib/python/site-packages (from transformers<5,>=4.27.0->recommenders) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from transformers<5,>=4.27.0->recommenders) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from transformers<5,>=4.27.0->recommenders) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from transformers<5,>=4.27.0->recommenders) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from transformers<5,>=4.27.0->recommenders) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5,>=4.27.0->recommenders) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5,>=4.27.0->recommenders) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/newt/Library/Python/3.9/lib/python/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (25.1.0)
# Requirement already satisfied: blinker>=1.9.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (3.0.3)
# Requirement already satisfied: zope.event in /Users/newt/Library/Python/3.9/lib/python/site-packages (from gevent>=22.10.2->locust<3,>=2.12.2->recommenders) (6.0)
# Requirement already satisfied: zope.interface in /Users/newt/Library/Python/3.9/lib/python/site-packages (from gevent>=22.10.2->locust<3,>=2.12.2->recommenders) (8.0.1)
# Requirement already satisfied: greenlet>=3.2.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from gevent>=22.10.2->locust<3,>=2.12.2->recommenders) (3.2.4)
# Requirement already satisfied: brotli in /Users/newt/Library/Python/3.9/lib/python/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (1.2.0)
# Requirement already satisfied: urllib3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2.6.2)
# Requirement already satisfied: zipp>=3.20 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.3->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (3.23.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (1.6.0)
# Requirement already satisfied: decorator in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (2.19.2)
# Requirement already satisfied: stack-data in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/newt/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8,>=6.5.5->recommenders) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.1.1)
# Requirement already satisfied: fqdn in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: isoduration in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.1.0)
# Requirement already satisfied: uri-template in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (24.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (3.2.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (6.5.2)
# Requirement already satisfied: beautifulsoup4 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: webencodings in /Users/newt/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.21.2)
# Requirement already satisfied: pydantic in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.12.5)
# Requirement already satisfied: typeguard in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (4.4.4)
# Requirement already satisfied: typing_inspect>=0.6.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.9.0)
# Requirement already satisfied: hypothesis>=6.92.7 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (6.141.1)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->locust<3,>=2.12.2->recommenders) (3.4.4)
# Requirement already satisfied: lark>=1.2.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from typing_inspect>=0.6.0->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (1.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.0.0)
# Requirement already satisfied: pycparser in /Users/newt/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (2.8.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook<8,>=6.5.5->recommenders) (1.4.0)
# Requirement already satisfied: mpmath in /Users/newt/Library/Python/3.9/lib/python/site-packages (from powerlaw->cornac<3,>=1.15.2->recommenders) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.4.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/newt/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/newt/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.1->notebook<8,>=6.5.5->recommenders) (0.2.3)

# %%
import sys
import logging
import numpy as np
import pandas as pd
from sklearn.preprocessing import minmax_scale

from recommenders.utils.timer import Timer
from recommenders.datasets import movielens
from recommenders.utils.python_utils import binarize
from recommenders.datasets.python_splitters import python_stratified_split
from recommenders.models.sar import SAR
from recommenders.evaluation.python_evaluation import (
    map,
    ndcg_at_k,
    precision_at_k,
    recall_at_k,
    rmse,
    mae,
    logloss,
    rsquared,
    exp_var
)
from recommenders.utils.notebook_utils import store_metadata

# %load_ext autoreload
# %autoreload 2

print(f"System version: {sys.version}")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# System version: 3.9.6 (default, Apr 30 2025, 02:07:17)
# [Clang 17.0.0 (clang-1700.0.13.5)]
# NumPy version: 2.0.2
# Pandas version: 2.3.3

# %% [markdown]
# # 1 Load Data
#
# SAR is intended to be used on interactions with the following schema:
# `<User ID>, <Item ID>,<Time>,[<Event Type>], [<Event Weight>]`.
#
# Each row represents a single interaction between a user and an item. These interactions might be different types of events on an e-commerce website, such as a user clicking to view an item, adding it to a shopping basket, following a recommendation link, and so on. Each event type can be assigned a different weight, for example, we might assign a “buy” event a weight of 10, while a “view” event mig－ht only have a weight of 1.
#
# The MovieLens dataset is well formatted interactions of Users providing Ratings to Movies (movie ratings are used as the event weight) - we will use it for the rest of the example.

# %%
# top k items to recommend
TOP_K = 10

# Select MovieLens data size: 100k, 1m, 10m, or 20m
MOVIELENS_DATA_SIZE = "100k"

# %% [markdown]
# ### 1.1 Download and use the MovieLens Dataset

# %%
data = movielens.load_pandas_df(
    size=MOVIELENS_DATA_SIZE
)

# Convert the float precision to 32-bit in order to reduce memory consumption 
data["rating"] = data["rating"].astype(np.float32)

data.head()
# Out:
# 2025-12-24 16:02:47,922 DEBUG    Starting new HTTPS connection (1): files.grouplens.org:443
# 2025-12-24 16:02:48,714 DEBUG    https://files.grouplens.org:443 "GET /datasets/movielens/ml-100k.zip HTTP/1.1" 200 4924029
# 2025-12-24 16:02:48,716 INFO     Downloading https://files.grouplens.org/datasets/movielens/ml-100k.zip
# 100%|██████████| 4.81k/4.81k [00:02<00:00, 2.09kKB/s]
#    userID  itemID  rating  timestamp
# 0     196     242     3.0  881250949
# 1     186     302     3.0  891717742
# 2      22     377     1.0  878887116
# 3     244      51     2.0  880606923
# 4     166     346     1.0  886397596

# %% [markdown]
# ### 1.2 Split the data using the python random splitter provided in utilities:
#
# We split the full dataset into a `train` and `test` dataset to evaluate performance of the algorithm against a held-out set not seen during training. Because SAR generates recommendations based on user preferences, all users that are in the test set must also exist in the training set. For this case, we can use the provided `python_stratified_split` function which holds out a percentage (in this case 25%) of items from each user, but ensures all users are in both `train` and `test` datasets. Other options are available in the `dataset.python_splitters` module which provide more control over how the split occurs.

# %%
train, test = python_stratified_split(data, ratio=0.75, col_user="userID", col_item="itemID", seed=42)

# %%
print("""
Train:
Total Ratings: {train_total}
Unique Users: {train_users}
Unique Items: {train_items}

Test:
Total Ratings: {test_total}
Unique Users: {test_users}
Unique Items: {test_items}
""".format(
    train_total=len(train),
    train_users=len(train['userID'].unique()),
    train_items=len(train['itemID'].unique()),
    test_total=len(test),
    test_users=len(test['userID'].unique()),
    test_items=len(test['itemID'].unique()),
))
# Out:
# Train:
# Total Ratings: 74992
# Unique Users: 943
# Unique Items: 1653
#
# Test:
# Total Ratings: 25008
# Unique Users: 943
# Unique Items: 1444

# %% [markdown]
# # 2 Train the SAR Model

# %% [markdown]
# ### 2.1 Instantiate the SAR algorithm and set the index
#
# We will use the single node implementation of SAR and specify the column names to match our dataset (timestamp is an optional column that is used and can be removed if your dataset does not contain it).
#
# Other options are specified to control the behavior of the algorithm as described in the [deep dive notebook](../02_model_collaborative_filtering/sar_deep_dive.ipynb).

# %%
# Configure logging to show debug-level messages with timestamps and severity. 
logging.basicConfig(level=logging.DEBUG, 
                    format='%(asctime)s %(levelname)-8s %(message)s')

#set up default col for SAR
model = SAR(
    col_user="userID",
    col_item="itemID",
    col_rating="rating",
    col_timestamp="timestamp",
    # jaccard similarity 兩個item 相似度的指標（重疊程度）
    similarity_type="jaccard", 
    time_decay_coefficient=30, 
    timedecay_formula=True,
    normalize=True
)

# %% [markdown]
# ### 2.2 Train the SAR model on our training data, and get the top-k recommendations for our testing data
#
# SAR first computes an item-to-item ***co-occurence matrix***. Co-occurence represents the number of times two items appear together for any given user. Once we have the co-occurence matrix, we compute an ***item similarity matrix*** by rescaling the cooccurences by a given metric (Jaccard similarity in this example).
#
# We also compute an ***affinity matrix*** to capture the strength of the relationship between each user and each item. Affinity is driven by different types (like *rating* or *viewing* a movie), and by the time of the event.
#
# Recommendations are achieved by multiplying the affinity matrix $A$ and the similarity matrix $S$. The result is a ***recommendation score matrix*** $R$. We compute the ***top-k*** results for each user in the `recommend_k_items` function seen below.
#
# A full walkthrough of the SAR algorithm can be found [here](../02_model_collaborative_filtering/sar_deep_dive.ipynb).

# %%
with Timer() as train_time:
    model.fit(train)

print("Took {} seconds for training.".format(train_time.interval))
# Out:
# 2025-12-24 16:02:51,257 INFO     Collecting user affinity matrix
# 2025-12-24 16:02:51,258 INFO     Calculating time-decayed affinities
# 2025-12-24 16:02:51,265 INFO     Creating index columns
# 2025-12-24 16:02:51,292 INFO     Calculating normalization factors
# 2025-12-24 16:02:51,300 INFO     Building user affinity sparse matrix
# 2025-12-24 16:02:51,302 INFO     Calculating item co-occurrence
# 2025-12-24 16:02:51,377 INFO     Calculating item similarity
# 2025-12-24 16:02:51,377 INFO     Using jaccard based similarity
# 2025-12-24 16:02:51,408 INFO     Done training
# Took 0.15509883400000035 seconds for training.

# %%
with Timer() as test_time:
    # recommend k items for each user in the test set, remove_seen=True means do not recommend items the user has already seen
    top_k = model.recommend_k_items(test, top_k=TOP_K, remove_seen=True)

print("Took {} seconds for prediction.".format(test_time.interval))
# Out:
# 2025-12-24 16:02:51,421 INFO     Calculating recommendation scores
# 2025-12-24 16:02:51,473 INFO     Removing seen items
# Took 0.06677804199989623 seconds for prediction.

# %%
# top_k means top k recommended items for each user, the higher the prediction the more likely the user will like the item
print(top_k)
top_k[top_k['userID'] == 943]
# Out:
#        userID  itemID  prediction
# 0           1     433    2.910697
# 1           1     204    2.906224
# 2           1     403    2.906136
# 3           1     174    2.870639
# 4           1      70    2.863253
# ...       ...     ...         ...
# 18855     943      88    2.956596
# 18856     943     173    2.950848
# 18857     943      95    2.931581
# 18858     943      77    2.931088
# 18859     943      71    2.928913
#
# [18860 rows x 3 columns]
#        userID  itemID  prediction
# 18840     943      82    3.366127
# 18841     943     568    3.331289
# 18842     943     550    3.306152
# 18843     943     176    3.241390
# 18844     943      96    3.176559
# 18845     943     144    3.110121
# 18846     943     265    3.109271
# 18847     943     231    3.107126
# 18848     943     423    3.080639
# 18849     943      97    3.079949
# 18850     943     183    3.074007
# 18851     943     215    3.037201
# 18852     943       4    3.028175
# 18853     943     559    3.025890
# 18854     943     168    3.014228
# 18855     943      88    2.956596
# 18856     943     173    2.950848
# 18857     943      95    2.931581
# 18858     943      77    2.931088
# 18859     943      71    2.928913

# %% [markdown]
# ### 2.3. Evaluate how well SAR performs
#
# We evaluate how well SAR performs for a few common ranking metrics provided in the `python_evaluation` module. We will consider the Mean Average Precision (MAP), Normalized Discounted Cumalative Gain (NDCG), Precision, and Recall for the top-k items per user we computed with SAR. User, item and rating column names are specified in each evaluation method.

# %%
# Ranking metrics
#this is about putting the user's favorite items on the top of the recommendation list
eval_map = map(test, top_k, col_user="userID", col_item="itemID", col_rating="rating", k=TOP_K)
eval_ndcg = ndcg_at_k(test, top_k, col_user="userID", col_item="itemID", col_rating="rating", k=TOP_K)
eval_precision = precision_at_k(test, top_k, col_user="userID", col_item="itemID", col_rating="rating", k=TOP_K)
eval_recall = recall_at_k(test, top_k, col_user="userID", col_item="itemID", col_rating="rating", k=TOP_K)

# %%
# Rating metrics
#compare actual ratings with predicted ratings
eval_rmse = rmse(test, top_k, col_user="userID", col_item="itemID", col_rating="rating")
eval_mae = mae(test, top_k, col_user="userID", col_item="itemID", col_rating="rating")
eval_rsquared = rsquared(test, top_k, col_user="userID", col_item="itemID", col_rating="rating")
eval_exp_var = exp_var(test, top_k, col_user="userID", col_item="itemID", col_rating="rating")

# %%
positivity_threshold = 2
test_bin = test.copy()
#binarize : covert the rating into 0 or 1(like or dislike) anything above 2 is 1, else 0
test_bin["rating"] = binarize(test_bin["rating"], positivity_threshold)

top_k_prob = top_k.copy()
#normalize predictions to [0, 1]
top_k_prob["prediction"] = minmax_scale(top_k_prob["prediction"].astype(float))

#caculate logloss
eval_logloss = logloss(
    test_bin, top_k_prob, col_user="userID", col_item="itemID", col_rating="rating"
)

# %%
print("Model:\t",
      "Top K:\t%d" % TOP_K,
      "MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall,
      "RMSE:\t%f" % eval_rmse,
      "MAE:\t%f" % eval_mae,
      "R2:\t%f" % eval_rsquared,
      "Exp var:\t%f" % eval_exp_var,
      "Logloss:\t%f" % eval_logloss,
      sep='\n')
# Out:
# Model:
# Top K:	20
# MAP:	0.136826
# NDCG:	0.367130
# Precision@K:	0.263945
# Recall@K:	0.266500
# RMSE:	1.262854
# MAE:	1.063496
# R2:	-0.590732
# Exp var:	0.083256
# Logloss:	0.599933

# %%
#basically we find all the rating in test for user 54, then sort by rating and take top k
#then compare with the recommendation(created by sar model) 
#use column "prediction" to see how well the model did
user_id = 54

# Ground truth items the user has rated in the test set(user actually liked)
#fine user which id is 54, sorted by rating, then take top k(slice)
ground_truth = test[test["userID"] == user_id].sort_values(
    by="rating", ascending=False
)[:TOP_K]
#create recommendation for the user
prediction = model.recommend_k_items(
    pd.DataFrame(dict(userID=[user_id])), remove_seen=True
)
#merge ground truth and prediction 
df = pd.merge(ground_truth, prediction, on=["userID", "itemID"], how="left")
df.head(10)
# Out:
# 2025-12-24 16:02:51,836 INFO     Calculating recommendation scores
# 2025-12-24 16:02:51,837 INFO     Removing seen items
#    userID  itemID  rating  timestamp  prediction
# 0      54     327     5.0  880928893         NaN
# 1      54     272     5.0  890608175         NaN
# 2      54     742     5.0  880934806    1.950736
# 3      54     147     5.0  880935959         NaN
# 4      54     240     4.0  880936500         NaN
# 5      54     258     4.0  880928745    2.100102
# 6      54     118     4.0  880937813    1.864598
# 7      54     302     4.0  880928519         NaN
# 8      54     307     4.0  891813846         NaN
# 9      54     595     3.0  880937813         NaN

# %% [markdown]
# Above, we see that one of the highest rated items from the test set was recovered by the model's top-k recommendations, however the others were not. Offline evaluations are difficult as they can only use what was seen previously in the test set and may not represent the user's actual preferences across the entire set of items. Adjustments to how the data is split, algorithm is used and hyper-parameters can improve the results here.

# %%
# Record results for tests - ignore this cell
store_metadata("map", eval_map)
store_metadata("ndcg", eval_ndcg)
store_metadata("precision", eval_precision)
store_metadata("recall", eval_recall)
store_metadata("train_time", train_time.interval)
store_metadata("test_time", test_time.interval)
